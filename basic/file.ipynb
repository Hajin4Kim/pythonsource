# %%
# 파일 생성
# open("경로", mode)
# mode == r : read, w: write( 기존 내용 제거하고 작성), a: append(기존내용에 추가 작성)

f = open("./test1.txt", "w")
f.write("Hello")
f.close()

# %%
f = open("./test1.txt", "w", encoding="utf-8")
f.write("안녕하세요")
f.write("\n")
f.write("반갑습니다")
f.close()

# %%
f = open("./test1.txt", "w", encoding="utf-8")
for i in range(1, 11):
  msg = f"{i} 번째 줄 입니다\n"
  f.write(msg)
f.close()

# %%
f = open("./test1.txt", "a", encoding="utf-8")
for i in range(1, 11):
  f.write("안녕하세요")
f.close()

# %%
list1 = ["홍길동", "김진수", "송수영"]

f = open("./test1.txt", "w", encoding="utf-8")
for i in list1:
  f.write(i+"\n")

f.close()

# %%
f = open("./test1.txt", "w", encoding="utf-8")
f.writelines(list1)

# %%
dict1 = {"name": "hong", "age":25, "addr": "서울"}
f = open("./test1.txt", "w", encoding="utf-8")
f.writelines(dict1) # key 값만 저장됨
f.close()

# %%
f = open("./test1.txt", "w", encoding="utf-8")
for k,v in dict1.items():
  f.writelines(f"{k} : {v}\n")
f.close()

# %%
import random

hanguls = list("가나다라마바사아자차카타파하")
f = open("./info.txt", "w", encoding="utf-8")
for i in range(1000):
  name = random.choice(hanguls) + random.choice(hanguls)
  weight = random.randrange(40, 100)
  height = random.randrange(140, 200)
  f.writelines(f"{name}, {weight}, {height}\n")
f.close()

# %%
f = open("./test1.txt", "r", encoding="utf-8")
f.read()
# Out:
# 'name : hong\nage : 25\naddr : 서울\n'

# %%
f = open("./test1.txt", "r", encoding="utf-8")
for c in f:
  # print(c)
  print(c.strip()) # enter 공백 제거
# Out:
# name : hong
# age : 25
# addr : 서울

# %%
f = open("./review.txt", "r", encoding="utf-8")
f.read() # \n 으로 표현된다
# Out:
# 'The film, projected in the form of animation,\nimparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,\nwhich eventually paves the path for gaining a fresh perspective on an age-old problem.\nThe story also happens to centre around two parallel characters, Shundi King and Hundi King,\nwho are twins, but they constantly fight over unresolved issues planted in their minds\nby external forces from within their very own units.'

# %%
f = open("./review.txt", "r", encoding="utf-8")
line = f.readline() # 한 줄 읽기
while line:
  print(line, end="")
  line = f.readline()
# f.read()
# f.close()
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
f = open("./review.txt", "r", encoding="utf-8")
lines = f.readlines() # 파일 전체 내용을 리스트로 리턴
lines
# Out:
# ['The film, projected in the form of animation,\n',
#  'imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,\n',
#  'which eventually paves the path for gaining a fresh perspective on an age-old problem.\n',
#  'The story also happens to centre around two parallel characters, Shundi King and Hundi King,\n',
#  'who are twins, but they constantly fight over unresolved issues planted in their minds\n',
#  'by external forces from within their very own units.']

# %%
f = open("./review.txt", "r", encoding="utf-8")
lines = f.readlines()
for line in lines:
  print(line, end="")
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
# score.txt 읽어온 후 합계와 평균 구한 후 출력
f = open("./score.txt", "r", encoding="utf-8")
scores = []
for num in f:
  scores.append(int(num))

print(f"합: {sum(scores)}, 평균: {sum(scores)/len(scores)}")
# Out:
# 합: 520, 평균: 86.66666666666667

# %%
# sample.txt 읽은 후 합계와 평균 구하기
# result.txt 작성(구한 합계와 평균 기록)
f = open("./sample.txt", "r", encoding="utf-8")
scores = []
for num in f:
  scores.append(int(num))
writes = (f"합: {sum(scores)}, 평균: {sum(scores)/len(scores)}")

f1 = open("./result.txt", "w", encoding="utf-8")
f1.write(writes)
f1.close()

# %%
# info.txt 읽기
f = open("./info.txt", "r", encoding="utf-8")

for info in f:
  name, weight, height = info.strip().split(", ")
  
# BMI 지수 계산 후 화면에 출력
  bmi =  int(weight) / (int(height) / 100) ** 2

# 결과 : 과체중
  if 25 <= bmi:
    result = "과체중"
  elif 18.5 <= bmi:
    result = "정상체중"
  else:
    result = "저체중"

# 타차, 66, 158
  print(name, weight, height)
# 이름 : 타차
  print(f"이름 : {name}")
# 몸무게 : 66
  print(f"몸무게 : {weight}")
# 키 : 158
  print(f"키 : {height}")
# BMI : 33.156 (BMI = weight / (height / 100) ** 2)
  print(f"BMI : {bmi}")
# [출력결과]
  print(f"결과 : {result}\n")
# Out:
# 하다 98 161
# 이름 : 하다
# 몸무게 : 98
# 키 : 161
# BMI : 37.80718336483932
# 결과 : 과체중
#
# 다다 75 147
# 이름 : 다다
# 몸무게 : 75
# 키 : 147
# BMI : 34.70776065528253
# 결과 : 과체중
#
# 파마 78 169
# 이름 : 파마
# 몸무게 : 78
# 키 : 169
# BMI : 27.309968138370508
# 결과 : 과체중
#
# 차다 77 164
# 이름 : 차다
# 몸무게 : 77
# 키 : 164
# BMI : 28.628792385484836
# 결과 : 과체중
#
# 하라 51 192
# 이름 : 하라
# 몸무게 : 51
# 키 : 192
# BMI : 13.834635416666668
# 결과 : 저체중
#
# 차다 54 152
# 이름 : 차다
# 몸무게 : 54
# 키 : 152
# BMI : 23.372576177285318
# 결과 : 정상체중
#
# 사다 61 173
# 이름 : 사다
# 몸무게 : 61
# 키 : 173
# BMI : 20.381569714992146
# 결과 : 정상체중
#
# 타아 56 151
# 이름 : 타아
# 몸무게 : 56
# 키 : 151
# BMI : 24.560326301478007
# 결과 : 정상체중
#
# 아나 53 153
# 이름 : 아나
# 몸무게 : 53
# 키 : 153
# BMI : 22.64086462471699
# 결과 : 정상체중
#
# 마파 75 160
# 이름 : 마파
# 몸무게 : 75
# 키 : 160
# BMI : 29.296874999999993
# 결과 : 과체중
#
# 라라 93 174
# 이름 : 라라
# 몸무게 : 93
# 키 : 174
# BMI : 30.71739992072929
# 결과 : 과체중
#
# 나카 59 198
# 이름 : 나카
# 몸무게 : 59
# 키 : 198
# BMI : 15.049484746454445
# 결과 : 저체중
#
# ...

# %%
ord("가")
chr(ord("가"))
chr(44032)
# Out:
# '가'

# %%
while True:
  no = int(input("1. 암호화 | 2. 복호화 | 3. 종료"))
  if no == 1:
    # origin 읽은 후 암호화 후 encryption.txt 로 저장
    f = open("./origin.txt", "r", encoding="utf-8")
    content = f.read()

    f1 = open("./encryption.txt", "w", encoding="utf-8")
    for c in content:
      f1.write(chr(ord(c) + 100))

  elif no == 2:
    # encryption.txt 를 읽은 후 원래 문자대로 화면 출력
    f2 = open("./encryption.txt", "r", encoding="utf-8")
    content = f2.read()
    for i in range(len(content)):
      print(chr(ord(content[i]) - 100), end="")
  else:
    break
# Out:
# 안녕하세요.
# 이 파일은 암호화 시킬 파일입니다.

# %%
# close() 자동 호출

with open("./origin.txt", "r", encoding="utf-8") as f1:
  print(f1.read())
# Out:
# 안녕하세요.
# 이 파일은 암호화 시킬 파일입니다.
